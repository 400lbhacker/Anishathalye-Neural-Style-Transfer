# %% [markdown]
# this is a compatability fix of the resulting source code: https://github.com/anishathalye/neural-style

# %% [markdown]
# Run the below box just once, this downloads the github src, the VGG model and properly configures prerequesites.

# %%
# !git clone https://github.com/anishathalye/neural-style
# !wget https://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# !pip install scipy==1.1.0
# %tensorflow_version 1.x
# !python /content/neural-style/neural_style.py --help
# Out:
# Cloning into 'neural-style'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 325 (delta 1), reused 6 (delta 1), pack-reused 314
# Receiving objects: 100% (325/325), 2.65 MiB | 31.51 MiB/s, done.
# Resolving deltas: 100% (167/167), done.
# --2021-04-08 01:02:08--  https://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Resolving www.vlfeat.org (www.vlfeat.org)... 64.90.48.57
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 534904783 (510M)
# Saving to: ‘imagenet-vgg-verydeep-19.mat’
#
# imagenet-vgg-veryde 100%[===================>] 510.12M  35.3MB/s    in 15s
#
# 2021-04-08 01:02:22 (34.8 MB/s) - ‘imagenet-vgg-verydeep-19.mat’ saved [534904783/534904783]
#
# ...
#      |████████████████████████████████| 31.2MB 87kB/s
# ...

# %% [markdown]
# And this is where you begin with style transfer and configure to your desired specifications

# %%
# !python /content/neural-style/neural_style.py --network /content/imagenet-vgg-verydeep-19.mat --content /content/1.jpg --styles /content/style.jpg --output /content/out.jpg
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration  541/1000 (58 sec elapsed, 47 sec remaining)
# Iteration  542/1000 (58 sec elapsed, 47 sec remaining)
# Iteration  543/1000 (58 sec elapsed, 46 sec remaining)
# Iteration  544/1000 (58 sec elapsed, 46 sec remaining)
# Iteration  545/1000 (58 sec elapsed, 46 sec remaining)
# Iteration  546/1000 (59 sec elapsed, 46 sec remaining)
# Iteration  547/1000 (59 sec elapsed, 46 sec remaining)
# Iteration  548/1000 (59 sec elapsed, 46 sec remaining)
# Iteration  549/1000 (59 sec elapsed, 46 sec remaining)
# Iteration  550/1000 (59 sec elapsed, 46 sec remaining)
# Iteration  551/1000 (59 sec elapsed, 46 sec remaining)
# Iteration  552/1000 (59 sec elapsed, 46 sec remaining)
# Iteration  553/1000 (59 sec elapsed, 45 sec remaining)
# Iteration  554/1000 (59 sec elapsed, 45 sec remaining)
# Iteration  555/1000 (59 sec elapsed, 45 sec remaining)
# Iteration  556/1000 (1 min 0 sec elapsed, 45 sec remaining)
# ...
